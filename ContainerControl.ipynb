# %% [markdown]
# ### Initialise

# %%
#!/usr/bin/python3

# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
import os
import subprocess
import sys
import warnings
currPth = os.getcwd()
warnings.filterwarnings("ignore")

# %%
import time
import datetime
import pandas as pd
import numpy as np

# %% [markdown]
# ### SQL Container

# %%
bashCommand = "sudo docker run -i -t --name legioSQL --net legionet --ip 172.50.0.20 -d -p 31330:3306 legiosql"
process = subprocess.Popen(bashCommand.split(), stdout=subprocess.PIPE)
output, error = process.communicate()

# %% [markdown]
# ### IB Gateways

# %% [markdown]
# #### Initialise

# %%
ibGateways = [['legioIBGW_ASIA1','172.50.0.30','31350'],['legioIBGW_ASIA2','172.50.0.31','31351'],
              ['legioIBGW_ASIA3','172.50.0.32','31352'],['legioIBGW_USA1','172.50.0.33','31353'],
              ['legioIBGW_USA2','172.50.0.34','31354'],['legioIBGW_USA3','172.50.0.35','31355'],
              ['legioIBGW_EUR1','172.50.0.36','31356'],['legioIBGW_EUR2','172.50.0.37','31357'],
              ['legioIBGW_EUR3','172.50.0.38','31358']]

# %% [markdown]
# #### Creation

# %%
for ibgw in ibGateways:
    #print("sudo docker run -i -t --name "+ibgw[0]+" --net legionet --ip "+ibgw[1]+" -d -p "+ibgw[2]+":5900 legioib")
    bashCommand = "sudo docker run -i -t --name "+ibgw[0]+" --net legionet --ip "+ibgw[1]+" -d -p "+ibgw[2]+":5900 legioib"
    process = subprocess.Popen(bashCommand.split(), stdout=subprocess.PIPE)
    output, error = process.communicate()
    time.sleep(2)

# %% [markdown]
# #### Start and Stop

# %%
for ibContainer in ibGateways:
    bashCommand = "sudo docker stop "+ibContainer[0]    
    process = subprocess.Popen(bashCommand.split(), stdout=subprocess.PIPE)
    output, error = process.communicate()
    time.sleep(1)

# %%
for ibContainer in ibGateways:
    bashCommand = "sudo docker start "+ibContainer[0]    
    process = subprocess.Popen(bashCommand.split(), stdout=subprocess.PIPE)
    output, error = process.communicate()
    time.sleep(1)

# %%
for ibContainer in ibGateways:
    bashCommand = "sudo docker rm "+ibContainer[0]    
    process = subprocess.Popen(bashCommand.split(), stdout=subprocess.PIPE)
    output, error = process.communicate()
    time.sleep(1)

# %% [markdown]
# ### Data Processors

# %% [markdown]
# #### Initialise

# %%
baseConfigInfo = pd.read_csv("~/LegioECSFiles-master/BaseConfigInfo.csv")

# %%
baseConfigInfo
# Out:
#     Symbol BaseCode Currency IBGatewayName  IBGatewayIP IBAccount_Data  \
# 0   AUDCAD      AUD      CAD    IBGW_ASIA1  172.50.0.30     legio50050
# 1   AUDCHF      AUD      CHF    IBGW_ASIA1  172.50.0.30     legio50050
# 2   AUDCNH      AUD      CNH    IBGW_ASIA1  172.50.0.30     legio50050
# 3   AUDHKD      AUD      HKD    IBGW_ASIA1  172.50.0.30     legio50050
# 4   AUDJPY      AUD      JPY    IBGW_ASIA1  172.50.0.30     legio50050
# 5   AUDNZD      AUD      NZD    IBGW_ASIA1  172.50.0.30     legio50050
# 6   AUDSGD      AUD      SGD    IBGW_ASIA2  172.50.0.31     legio50051
# 7   AUDUSD      AUD      USD    IBGW_ASIA2  172.50.0.31     legio50051
# 8   CNHHKD      CNH      HKD    IBGW_ASIA2  172.50.0.31     legio50051
# 9   CNHJPY      CNH      JPY    IBGW_ASIA2  172.50.0.31     legio50051
# 10  HKDJPY      HKD      JPY    IBGW_ASIA2  172.50.0.31     legio50051
# 11  NZDCAD      NZD      CAD    IBGW_ASIA2  172.50.0.31     legio50051
# 12  NZDCHF      NZD      CHF    IBGW_ASIA3  172.50.0.32     legio50052
# 13  NZDJPY      NZD      JPY    IBGW_ASIA3  172.50.0.32     legio50052
# 14  NZDUSD      NZD      USD    IBGW_ASIA3  172.50.0.32     legio50052
# 15  SGDCNH      SGD      CNH    IBGW_ASIA3  172.50.0.32     legio50052
# 16  SGDJPY      SGD      JPY    IBGW_ASIA3  172.50.0.32     legio50052
# 17  CADHKD      CAD      HKD    IBGW_ASIA3  172.50.0.32     legio50052
# 18  EURAUD      EUR      AUD     IBGW_EUR1  172.50.0.36     legio50056
# 19  EURCAD      EUR      CAD     IBGW_EUR1  172.50.0.36     legio50056
# 20  EURCHF      EUR      CHF     IBGW_EUR1  172.50.0.36     legio50056
# 21  EURGBP      EUR      GBP     IBGW_EUR1  172.50.0.36     legio50056
# 22  GBPJPY      GBP      JPY     IBGW_EUR1  172.50.0.36     legio50056
# 23  GBPMXN      GBP      MXN     IBGW_EUR1  172.50.0.36     legio50056
# 24  GBPNOK      GBP      NOK     IBGW_EUR2  172.50.0.37     legio50057
# 25  GBPNZD      GBP      NZD     IBGW_EUR2  172.50.0.37     legio50057
# 26  GBPSEK      GBP      SEK     IBGW_EUR2  172.50.0.37     legio50057
# 27  GBPUSD      GBP      USD     IBGW_EUR2  172.50.0.37     legio50057
# 28  GBPZAR      GBP      ZAR     IBGW_EUR2  172.50.0.37     legio50057
# 29  CHFCNH      CHF      CNH     IBGW_EUR2  172.50.0.37     legio50057
# 30  CHFDKK      CHF      DKK     IBGW_EUR3  172.50.0.38     legio50058
# 31  CHFJPY      CHF      JPY     IBGW_EUR3  172.50.0.38     legio50058
# 32  CHFNOK      CHF      NOK     IBGW_EUR3  172.50.0.38     legio50058
# 33  CHFSEK      CHF      SEK     IBGW_EUR3  172.50.0.38     legio50058
# 34  CHFZAR      CHF      ZAR     IBGW_EUR3  172.50.0.38     legio50058
# 35  CADCHF      CAD      CHF     IBGW_EUR3  172.50.0.38     legio50058
# 36  CADCNH      CAD      CNH      IBGW_US1  172.50.0.33     legio50053
# 37  CADJPY      CAD      JPY      IBGW_US1  172.50.0.33     legio50053
# 38  USDCAD      USD      CAD      IBGW_US1  172.50.0.33     legio50053
# 39  USDCHF      USD      CHF      IBGW_US1  172.50.0.33     legio50053
# 40  USDCNH      USD      CNH      IBGW_US1  172.50.0.33     legio50053
# 41  USDCZK      USD      CZK      IBGW_US1  172.50.0.33     legio50053
# 42  USDDKK      USD      DKK      IBGW_US2  172.50.0.34     legio50054
# 43  USDHKD      USD      HKD      IBGW_US2  172.50.0.34     legio50054
# 44  USDHUF      USD      HUF      IBGW_US2  172.50.0.34     legio50054
# 45  USDILS      USD      ILS      IBGW_US2  172.50.0.34     legio50054
# 46  USDJPY      USD      JPY      IBGW_US2  172.50.0.34     legio50054
# 47  USDMXN      USD      MXN      IBGW_US2  172.50.0.34     legio50054
# 48  USDNOK      USD      NOK      IBGW_US3  172.50.0.35     legio50055
# 49  USDPLN      USD      PLN      IBGW_US3  172.50.0.35     legio50055
# 50  USDRUB      USD      RUB      IBGW_US3  172.50.0.35     legio50055
# 51  USDSEK      USD      SEK      IBGW_US3  172.50.0.35     legio50055
# 52  USDSGD      USD      SGD      IBGW_US3  172.50.0.35     legio50055
# 53  USDZAR      USD      ZAR      IBGW_US3  172.50.0.35     legio50055
#
#     Jupyter Port     IPAddress  IB Client ID
# 0          31370   172.50.0.50         10001
# 1          31371   172.50.0.51         10002
# 2          31372   172.50.0.52         10003
# 3          31373   172.50.0.53         10004
# 4          31374   172.50.0.54         10005
# 5          31375   172.50.0.55         10006
# 6          31376   172.50.0.56         10007
# 7          31377   172.50.0.57         10008
# 8          31378   172.50.0.58         10009
# 9          31379   172.50.0.59         10010
# 10         31380   172.50.0.60         10011
# 11         31381   172.50.0.61         10012
# 12         31382   172.50.0.62         10013
# 13         31383   172.50.0.63         10014
# 14         31384   172.50.0.64         10015
# 15         31385   172.50.0.65         10016
# 16         31386   172.50.0.66         10017
# 17         31387   172.50.0.67         10018
# 18         31388   172.50.0.68         10019
# 19         31389   172.50.0.69         10020
# 20         31390   172.50.0.70         10021
# 21         31391   172.50.0.71         10022
# 22         31392   172.50.0.72         10023
# 23         31393   172.50.0.73         10024
# 24         31394   172.50.0.74         10025
# 25         31395   172.50.0.75         10026
# 26         31396   172.50.0.76         10027
# 27         31397   172.50.0.77         10028
# 28         31398   172.50.0.78         10029
# 29         31399   172.50.0.79         10030
# 30         31400   172.50.0.80         10031
# 31         31401   172.50.0.81         10032
# 32         31402   172.50.0.82         10033
# 33         31403   172.50.0.83         10034
# 34         31404   172.50.0.84         10035
# 35         31405   172.50.0.85         10036
# 36         31406   172.50.0.86         10037
# 37         31407   172.50.0.87         10038
# 38         31408   172.50.0.88         10039
# 39         31409   172.50.0.89         10040
# 40         31410   172.50.0.90         10041
# 41         31411   172.50.0.91         10042
# 42         31412   172.50.0.92         10043
# 43         31413   172.50.0.93         10044
# 44         31414   172.50.0.94         10045
# 45         31415   172.50.0.95         10046
# 46         31416   172.50.0.96         10047
# 47         31417   172.50.0.97         10048
# 48         31418   172.50.0.98         10049
# 49         31419   172.50.0.99         10050
# 50         31420  172.50.0.100         10051
# 51         31421  172.50.0.101         10052
# 52         31422  172.50.0.102         10053
# 53         31423  172.50.0.103         10054

# %% [markdown]
# #### Creation

# %%
counter = 0
for index, row in baseConfigInfo.iterrows():
    print(row['Symbol'])    
    #print("sudo docker run -i -t --name legioDP_"+row['Symbol']+" --net legionet --ip "+row['IPAddress']+" --link "+row['IBGatewayName']+" -d -p "+str(row['Jupyter Port'])+":8080 legiodp")
    bashCommand = "sudo docker run -i -t --name legioDP_"+row['Symbol']+" --net legionet --ip "+row['IPAddress']+" --link "+row['IBGatewayName']+" -d -p "+str(row['Jupyter Port'])+":8080 legiodp"
    process = subprocess.Popen(bashCommand.split(), stdout=subprocess.PIPE)
    output, error = process.communicate()
    time.sleep(1)
#     counter += 1
#     if counter == 6:
#         break
# Out:
# AUDCAD
# AUDCHF
# AUDCNH
# AUDHKD
# AUDJPY
# AUDNZD
# AUDSGD
# AUDUSD
# CNHHKD
# CNHJPY
# HKDJPY
# NZDCAD
# NZDCHF
# NZDJPY
# NZDUSD
# SGDCNH
# SGDJPY
# CADHKD
# EURAUD
# EURCAD
# EURCHF
# EURGBP
# GBPJPY
# GBPMXN
# GBPNOK
# GBPNZD
# GBPSEK
# GBPUSD
# GBPZAR
# CHFCNH
# CHFDKK
# CHFJPY
# CHFNOK
# CHFSEK
# CHFZAR
# CADCHF
# CADCNH
# CADJPY
# USDCAD
# USDCHF
# USDCNH
# USDCZK
# USDDKK
# USDHKD
# USDHUF
# USDILS
# USDJPY
# USDMXN
# USDNOK
# USDPLN
# USDRUB
# USDSEK
# USDSGD
# USDZAR

# %%
counter = 0
for index, row in baseConfigInfo.iterrows():
    #print(row['Symbol'])    
    print("sudo docker exec -it legioDP_"+row['Symbol']+" ./CreateMarketCodeFile.sh "+row['Symbol']+" && \\")    
#     bashCommand = "sudo docker exec -it legioDP_"+row['Symbol']+" '/CreateMarketSymbol.sh "+row['Symbol']+"'"
#     process = subprocess.Popen(bashCommand.split(), stdout=subprocess.PIPE)
#     output, error = process.communicate()
# Out:
# sudo docker exec -it legioDP_AUDCAD ./CreateMarketCodeFile.sh AUDCAD && \
# sudo docker exec -it legioDP_AUDCHF ./CreateMarketCodeFile.sh AUDCHF && \
# sudo docker exec -it legioDP_AUDCNH ./CreateMarketCodeFile.sh AUDCNH && \
# sudo docker exec -it legioDP_AUDHKD ./CreateMarketCodeFile.sh AUDHKD && \
# sudo docker exec -it legioDP_AUDJPY ./CreateMarketCodeFile.sh AUDJPY && \
# sudo docker exec -it legioDP_AUDNZD ./CreateMarketCodeFile.sh AUDNZD && \
# sudo docker exec -it legioDP_AUDSGD ./CreateMarketCodeFile.sh AUDSGD && \
# sudo docker exec -it legioDP_AUDUSD ./CreateMarketCodeFile.sh AUDUSD && \
# sudo docker exec -it legioDP_CNHHKD ./CreateMarketCodeFile.sh CNHHKD && \
# sudo docker exec -it legioDP_CNHJPY ./CreateMarketCodeFile.sh CNHJPY && \
# sudo docker exec -it legioDP_HKDJPY ./CreateMarketCodeFile.sh HKDJPY && \
# sudo docker exec -it legioDP_NZDCAD ./CreateMarketCodeFile.sh NZDCAD && \
# sudo docker exec -it legioDP_NZDCHF ./CreateMarketCodeFile.sh NZDCHF && \
# sudo docker exec -it legioDP_NZDJPY ./CreateMarketCodeFile.sh NZDJPY && \
# sudo docker exec -it legioDP_NZDUSD ./CreateMarketCodeFile.sh NZDUSD && \
# sudo docker exec -it legioDP_SGDCNH ./CreateMarketCodeFile.sh SGDCNH && \
# sudo docker exec -it legioDP_SGDJPY ./CreateMarketCodeFile.sh SGDJPY && \
# sudo docker exec -it legioDP_CADHKD ./CreateMarketCodeFile.sh CADHKD && \
# sudo docker exec -it legioDP_EURAUD ./CreateMarketCodeFile.sh EURAUD && \
# sudo docker exec -it legioDP_EURCAD ./CreateMarketCodeFile.sh EURCAD && \
# sudo docker exec -it legioDP_EURCHF ./CreateMarketCodeFile.sh EURCHF && \
# sudo docker exec -it legioDP_EURGBP ./CreateMarketCodeFile.sh EURGBP && \
# sudo docker exec -it legioDP_GBPJPY ./CreateMarketCodeFile.sh GBPJPY && \
# sudo docker exec -it legioDP_GBPMXN ./CreateMarketCodeFile.sh GBPMXN && \
# sudo docker exec -it legioDP_GBPNOK ./CreateMarketCodeFile.sh GBPNOK && \
# sudo docker exec -it legioDP_GBPNZD ./CreateMarketCodeFile.sh GBPNZD && \
# sudo docker exec -it legioDP_GBPSEK ./CreateMarketCodeFile.sh GBPSEK && \
# sudo docker exec -it legioDP_GBPUSD ./CreateMarketCodeFile.sh GBPUSD && \
# sudo docker exec -it legioDP_GBPZAR ./CreateMarketCodeFile.sh GBPZAR && \
# sudo docker exec -it legioDP_CHFCNH ./CreateMarketCodeFile.sh CHFCNH && \
# sudo docker exec -it legioDP_CHFDKK ./CreateMarketCodeFile.sh CHFDKK && \
# sudo docker exec -it legioDP_CHFJPY ./CreateMarketCodeFile.sh CHFJPY && \
# sudo docker exec -it legioDP_CHFNOK ./CreateMarketCodeFile.sh CHFNOK && \
# sudo docker exec -it legioDP_CHFSEK ./CreateMarketCodeFile.sh CHFSEK && \
# sudo docker exec -it legioDP_CHFZAR ./CreateMarketCodeFile.sh CHFZAR && \
# sudo docker exec -it legioDP_CADCHF ./CreateMarketCodeFile.sh CADCHF && \
# sudo docker exec -it legioDP_CADCNH ./CreateMarketCodeFile.sh CADCNH && \
# sudo docker exec -it legioDP_CADJPY ./CreateMarketCodeFile.sh CADJPY && \
# sudo docker exec -it legioDP_USDCAD ./CreateMarketCodeFile.sh USDCAD && \
# sudo docker exec -it legioDP_USDCHF ./CreateMarketCodeFile.sh USDCHF && \
# sudo docker exec -it legioDP_USDCNH ./CreateMarketCodeFile.sh USDCNH && \
# sudo docker exec -it legioDP_USDCZK ./CreateMarketCodeFile.sh USDCZK && \
# sudo docker exec -it legioDP_USDDKK ./CreateMarketCodeFile.sh USDDKK && \
# sudo docker exec -it legioDP_USDHKD ./CreateMarketCodeFile.sh USDHKD && \
# sudo docker exec -it legioDP_USDHUF ./CreateMarketCodeFile.sh USDHUF && \
# sudo docker exec -it legioDP_USDILS ./CreateMarketCodeFile.sh USDILS && \
# sudo docker exec -it legioDP_USDJPY ./CreateMarketCodeFile.sh USDJPY && \
# sudo docker exec -it legioDP_USDMXN ./CreateMarketCodeFile.sh USDMXN && \
# sudo docker exec -it legioDP_USDNOK ./CreateMarketCodeFile.sh USDNOK && \
# sudo docker exec -it legioDP_USDPLN ./CreateMarketCodeFile.sh USDPLN && \
# sudo docker exec -it legioDP_USDRUB ./CreateMarketCodeFile.sh USDRUB && \
# sudo docker exec -it legioDP_USDSEK ./CreateMarketCodeFile.sh USDSEK && \
# sudo docker exec -it legioDP_USDSGD ./CreateMarketCodeFile.sh USDSGD && \
# sudo docker exec -it legioDP_USDZAR ./CreateMarketCodeFile.sh USDZAR && \

# %% [markdown]
# #### Start and Stop

# %%
for index, row in baseConfigInfo.iterrows():
    print(row['Symbol'])    
    bashCommand = "sudo docker stop legioDP_"+row['Symbol']    
    process = subprocess.Popen(bashCommand.split(), stdout=subprocess.PIPE)
    output, error = process.communicate()
    time.sleep(1)
# Out:
# AUDCAD
# AUDCHF
# AUDCNH
# AUDHKD
# AUDJPY
# AUDNZD
# AUDSGD
# AUDUSD
# CNHHKD
# CNHJPY
# HKDJPY
# NZDCAD
# NZDCHF
# NZDJPY
# NZDUSD
# SGDCNH
# SGDJPY
# CADHKD
# EURAUD
# EURCAD
# EURCHF
# EURGBP
# GBPJPY
# GBPMXN
# GBPNOK
# GBPNZD
# GBPSEK
# GBPUSD
# GBPZAR
# CHFCNH
# CHFDKK
# CHFJPY
# CHFNOK
# CHFSEK
# CHFZAR
# CADCHF
# CADCNH
# CADJPY
# USDCAD
# USDCHF
# USDCNH
# USDCZK
# USDDKK
# USDHKD
# USDHUF
# USDILS
# USDJPY
# USDMXN
# USDNOK
# USDPLN
# USDRUB
# USDSEK
# USDSGD
# USDZAR

# %%
for index, row in baseConfigInfo.iterrows():
    print(row['Symbol'])    
    bashCommand = "sudo docker rm legioDP_"+row['Symbol']    
    process = subprocess.Popen(bashCommand.split(), stdout=subprocess.PIPE)
    output, error = process.communicate()
    time.sleep(1)
# Out:
# AUDCAD
# AUDCHF
# AUDCNH
# AUDHKD
# AUDJPY
# AUDNZD
# AUDSGD
# AUDUSD
# CNHHKD
# CNHJPY
# HKDJPY
# NZDCAD
# NZDCHF
# NZDJPY
# NZDUSD
# SGDCNH
# SGDJPY
# CADHKD
# EURAUD
# EURCAD
# EURCHF
# EURGBP
# GBPJPY
# GBPMXN
# GBPNOK
# GBPNZD
# GBPSEK
# GBPUSD
# GBPZAR
# CHFCNH
# CHFDKK
# CHFJPY
# CHFNOK
# CHFSEK
# CHFZAR
# CADCHF
# CADCNH
# CADJPY
# USDCAD
# USDCHF
# USDCNH
# USDCZK
# USDDKK
# USDHKD
# USDHUF
# USDILS
# USDJPY
# USDMXN
# USDNOK
# USDPLN
# USDRUB
# USDSEK
# USDSGD
# USDZAR

# %%
for index, row in baseConfigInfo.iterrows():
    print(row['Symbol'])    
    bashCommand = "sudo docker start legioDP_"+row['Symbol']    
    process = subprocess.Popen(bashCommand.split(), stdout=subprocess.PIPE)
    output, error = process.communicate()
    time.sleep(1)

# %% [markdown]
# #### Processing

# %%
counter = 0
for index, row in baseConfigInfo.iterrows():
    #print(row['Symbol'])    
    print("sudo docker exec -it legioDP_"+row['Symbol']+" python /root/LegioContainerFiles-master/RetrieveHistoricalData.py")
# Out:
# sudo docker exec -it legioDP_AUDCAD python /root/LegioContainerFiles-master/RetrieveHistoricalData.py
# sudo docker exec -it legioDP_AUDCHF python /root/LegioContainerFiles-master/RetrieveHistoricalData.py
# sudo docker exec -it legioDP_AUDCNH python /root/LegioContainerFiles-master/RetrieveHistoricalData.py
# sudo docker exec -it legioDP_AUDHKD python /root/LegioContainerFiles-master/RetrieveHistoricalData.py
# sudo docker exec -it legioDP_AUDJPY python /root/LegioContainerFiles-master/RetrieveHistoricalData.py
# sudo docker exec -it legioDP_AUDNZD python /root/LegioContainerFiles-master/RetrieveHistoricalData.py
# sudo docker exec -it legioDP_AUDSGD python /root/LegioContainerFiles-master/RetrieveHistoricalData.py
# sudo docker exec -it legioDP_AUDUSD python /root/LegioContainerFiles-master/RetrieveHistoricalData.py
# sudo docker exec -it legioDP_CNHHKD python /root/LegioContainerFiles-master/RetrieveHistoricalData.py
# sudo docker exec -it legioDP_CNHJPY python /root/LegioContainerFiles-master/RetrieveHistoricalData.py
# sudo docker exec -it legioDP_HKDJPY python /root/LegioContainerFiles-master/RetrieveHistoricalData.py
# sudo docker exec -it legioDP_NZDCAD python /root/LegioContainerFiles-master/RetrieveHistoricalData.py
# sudo docker exec -it legioDP_NZDCHF python /root/LegioContainerFiles-master/RetrieveHistoricalData.py
# sudo docker exec -it legioDP_NZDJPY python /root/LegioContainerFiles-master/RetrieveHistoricalData.py
# sudo docker exec -it legioDP_NZDUSD python /root/LegioContainerFiles-master/RetrieveHistoricalData.py
# sudo docker exec -it legioDP_SGDCNH python /root/LegioContainerFiles-master/RetrieveHistoricalData.py
# sudo docker exec -it legioDP_SGDJPY python /root/LegioContainerFiles-master/RetrieveHistoricalData.py
# sudo docker exec -it legioDP_CADHKD python /root/LegioContainerFiles-master/RetrieveHistoricalData.py
# sudo docker exec -it legioDP_EURAUD python /root/LegioContainerFiles-master/RetrieveHistoricalData.py
# sudo docker exec -it legioDP_EURCAD python /root/LegioContainerFiles-master/RetrieveHistoricalData.py
# sudo docker exec -it legioDP_EURCHF python /root/LegioContainerFiles-master/RetrieveHistoricalData.py
# sudo docker exec -it legioDP_EURGBP python /root/LegioContainerFiles-master/RetrieveHistoricalData.py
# sudo docker exec -it legioDP_GBPJPY python /root/LegioContainerFiles-master/RetrieveHistoricalData.py
# sudo docker exec -it legioDP_GBPMXN python /root/LegioContainerFiles-master/RetrieveHistoricalData.py
# sudo docker exec -it legioDP_GBPNOK python /root/LegioContainerFiles-master/RetrieveHistoricalData.py
# sudo docker exec -it legioDP_GBPNZD python /root/LegioContainerFiles-master/RetrieveHistoricalData.py
# sudo docker exec -it legioDP_GBPSEK python /root/LegioContainerFiles-master/RetrieveHistoricalData.py
# sudo docker exec -it legioDP_GBPUSD python /root/LegioContainerFiles-master/RetrieveHistoricalData.py
# sudo docker exec -it legioDP_GBPZAR python /root/LegioContainerFiles-master/RetrieveHistoricalData.py
# sudo docker exec -it legioDP_CHFCNH python /root/LegioContainerFiles-master/RetrieveHistoricalData.py
# sudo docker exec -it legioDP_CHFDKK python /root/LegioContainerFiles-master/RetrieveHistoricalData.py
# sudo docker exec -it legioDP_CHFJPY python /root/LegioContainerFiles-master/RetrieveHistoricalData.py
# sudo docker exec -it legioDP_CHFNOK python /root/LegioContainerFiles-master/RetrieveHistoricalData.py
# sudo docker exec -it legioDP_CHFSEK python /root/LegioContainerFiles-master/RetrieveHistoricalData.py
# sudo docker exec -it legioDP_CHFZAR python /root/LegioContainerFiles-master/RetrieveHistoricalData.py
# sudo docker exec -it legioDP_CADCHF python /root/LegioContainerFiles-master/RetrieveHistoricalData.py
# sudo docker exec -it legioDP_CADCNH python /root/LegioContainerFiles-master/RetrieveHistoricalData.py
# sudo docker exec -it legioDP_CADJPY python /root/LegioContainerFiles-master/RetrieveHistoricalData.py
# sudo docker exec -it legioDP_USDCAD python /root/LegioContainerFiles-master/RetrieveHistoricalData.py
# sudo docker exec -it legioDP_USDCHF python /root/LegioContainerFiles-master/RetrieveHistoricalData.py
# sudo docker exec -it legioDP_USDCNH python /root/LegioContainerFiles-master/RetrieveHistoricalData.py
# sudo docker exec -it legioDP_USDCZK python /root/LegioContainerFiles-master/RetrieveHistoricalData.py
# sudo docker exec -it legioDP_USDDKK python /root/LegioContainerFiles-master/RetrieveHistoricalData.py
# sudo docker exec -it legioDP_USDHKD python /root/LegioContainerFiles-master/RetrieveHistoricalData.py
# sudo docker exec -it legioDP_USDHUF python /root/LegioContainerFiles-master/RetrieveHistoricalData.py
# sudo docker exec -it legioDP_USDILS python /root/LegioContainerFiles-master/RetrieveHistoricalData.py
# sudo docker exec -it legioDP_USDJPY python /root/LegioContainerFiles-master/RetrieveHistoricalData.py
# sudo docker exec -it legioDP_USDMXN python /root/LegioContainerFiles-master/RetrieveHistoricalData.py
# sudo docker exec -it legioDP_USDNOK python /root/LegioContainerFiles-master/RetrieveHistoricalData.py
# sudo docker exec -it legioDP_USDPLN python /root/LegioContainerFiles-master/RetrieveHistoricalData.py
# sudo docker exec -it legioDP_USDRUB python /root/LegioContainerFiles-master/RetrieveHistoricalData.py
# sudo docker exec -it legioDP_USDSEK python /root/LegioContainerFiles-master/RetrieveHistoricalData.py
# sudo docker exec -it legioDP_USDSGD python /root/LegioContainerFiles-master/RetrieveHistoricalData.py
# sudo docker exec -it legioDP_USDZAR python /root/LegioContainerFiles-master/RetrieveHistoricalData.py

# %%
counter = 0
for index, row in baseConfigInfo.iterrows():
    print(row['Symbol'])   
    bashCommand = "sudo docker exec -it legioDP_"+row['Symbol']+" python /root/LegioContainerFiles-master/RetrieveHistoricalData.py"
    process = subprocess.Popen(bashCommand.split(), stdout=subprocess.PIPE)
    output, error = process.communicate()
    time.sleep(1)
    counter += 1
    if counter == 2:
        break
# Out:
# AUDCAD
# AUDCHF
